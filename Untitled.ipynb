# %%
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('Data.csv', encoding='latin-1')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(100)
# Out:
#     ATP  Location                          Tournament        Date  \
# 0     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 1     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 2     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 3     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 4     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 5     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 6     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 7     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 8     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 9     1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 10    1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 11    1  Adelaide  Australian Hardcourt Championships   3/01/2000
# 12    1  Adelaide  Australian Hardcourt Championships   3/01/2000
# ...

# %%
print(df.shape)
print(df.columns)
# Out:
# (46652, 54)
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'W1', 'L1',
#        'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets',
#        'Comment', 'CBW', 'CBL', 'GBW', 'GBL', 'IWW', 'IWL', 'SBW', 'SBL',
#        'B365W', 'B365L', 'B&WW', 'B&WL', 'EXW', 'EXL', 'PSW', 'PSL', 'WPts',
#        'LPts', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL'],
#       dtype='object')

# %% [markdown]
# Preprocessing
# Keep relevant features
# Clean and categorize data

# %%
relevant_columns = ['Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 
                    'Loser', 'WRank', 'LRank']
df = df[relevant_columns]
df.head()
# Out:
#                            Tournament       Date         Series    Court  \
# 0  Australian Hardcourt Championships  3/01/2000  International  Outdoor
# 1  Australian Hardcourt Championships  3/01/2000  International  Outdoor
# 2  Australian Hardcourt Championships  3/01/2000  International  Outdoor
# 3  Australian Hardcourt Championships  3/01/2000  International  Outdoor
# 4  Australian Hardcourt Championships  3/01/2000  International  Outdoor
#
#   Surface      Round  Best of       Winner           Loser WRank LRank
# 0    Hard  1st Round        3   Dosedel S.     Ljubicic I.    63    77
# 1    Hard  1st Round        3   Enqvist T.      Clement A.     5    56
# 2    Hard  1st Round        3    Escude N.   Baccanello P.    40   655
# 3    Hard  1st Round        3   Federer R.  Knippschild J.    65    87
# 4    Hard  1st Round        3  Fromberg R.   Woodbridge T.    81   198

# %%
print(df.isna().sum())
df[df.isna().any(axis=1)]

# Several matches do not have rankings for players.  I will assume these players were amateurs given wildcards or 
# or other low ranked players and assign a rank of 1000, the lowest possible rank on the ATP Tour
# Out:
# Tournament     0
# Date           0
# Series         0
# Court          0
# Surface        0
# Round          0
# Best of        0
# Winner         0
# Loser          0
# WRank         15
# LRank         71
# dtype: int64
#                                        Tournament        Date  \
# 10782                          Legg Mason Classic  28/07/2003
# 10799                          Legg Mason Classic  30/07/2003
# 10820                          Legg Mason Classic   1/08/2003
# 11646                          AAPT Championships   5/01/2004
# 11658                          AAPT Championships   7/01/2004
# 11668                          AAPT Championships   9/01/2004
# 11965                                 Siebel Open  11/02/2004
# 12824                        Grand Prix Hassan II  16/05/2004
# 13780                          Legg Mason Classic  17/08/2004
# 14557                                   TATA Open   3/01/2005
# 14616                               Heineken Open  10/01/2005
# ...

# %%
df = df.fillna(1000)
df.isna().sum()
# Out:
# Tournament    0
# Date          0
# Series        0
# Court         0
# Surface       0
# Round         0
# Best of       0
# Winner        0
# Loser         0
# WRank         0
# LRank         0
# dtype: int64
